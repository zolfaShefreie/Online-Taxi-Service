# %%
import pandas as pd
df = pd.read_csv("../data.csv", header=[0])

# %%
df.columns
df.loc[df['Lat'].idxmax()]
# Out:
# Date/Time    9/2/2014 13:39:00
# Lat                    41.3183
# Lon                    -74.124
# Base                    B02617
# Name: 287765, dtype: object

# %%
df.loc[df['Lon'].idxmax()]
# Out:
# Date/Time    9/16/2014 16:46:00
# Lat                     40.9231
# Lon                    -72.7163
# Base                     B02598
# Name: 162590, dtype: object

# %%
df.loc[df['Lat'].idxmin()]
# Out:
# Date/Time    9/27/2014 20:13:00
# Lat                     39.9897
# Lon                    -74.1423
# Base                     B02598
# Name: 252750, dtype: object

# %%
df.loc[df['Lon'].idxmin()]
# Out:
# Date/Time    9/16/2014 16:32:00
# Lat                     40.6406
# Lon                    -74.7736
# Base                     B02598
# Name: 162435, dtype: object

# %%
len(df[["Lon", "Lat"]].drop_duplicates())
# Out:
# 180473

# %%
df['Date/Time'].agg(['min', 'max'])
# Out:
# min    9/1/2014 0:00:00
# max    9/9/2014 9:59:00
# Name: Date/Time, dtype: object

# %%
list(df['Date/Time'].unique())
# Out:
# ['9/1/2014 0:01:00',
#  '9/1/2014 0:03:00',
#  '9/1/2014 0:06:00',
#  '9/1/2014 0:11:00',
#  '9/1/2014 0:12:00',
#  '9/1/2014 0:15:00',
#  '9/1/2014 0:16:00',
#  '9/1/2014 0:32:00',
#  '9/1/2014 0:33:00',
#  '9/1/2014 0:37:00',
#  '9/1/2014 0:38:00',
#  '9/1/2014 0:39:00',
#  '9/1/2014 0:48:00',
#  '9/1/2014 0:49:00',
#  '9/1/2014 1:08:00',
#  '9/1/2014 1:17:00',
#  '9/1/2014 1:19:00',
#  '9/1/2014 1:39:00',
#  '9/1/2014 1:41:00',
#  '9/1/2014 2:03:00',
#  '9/1/2014 2:13:00',
#  '9/1/2014 2:33:00',
#  '9/1/2014 2:39:00',
#  '9/1/2014 2:41:00',
#  '9/1/2014 3:18:00',
#  '9/1/2014 4:01:00',
#  '9/1/2014 4:06:00',
#  '9/1/2014 4:20:00',
#  '9/1/2014 4:34:00',
#  '9/1/2014 5:02:00',
#  '9/1/2014 5:11:00',
#  '9/1/2014 5:12:00',
#  '9/1/2014 5:16:00',
#  '9/1/2014 5:25:00',
#  '9/1/2014 5:29:00',
#  '9/1/2014 5:45:00',
#  '9/1/2014 5:55:00',
#  '9/1/2014 5:56:00',
#  '9/1/2014 6:04:00',
#  '9/1/2014 6:08:00',
#  '9/1/2014 6:14:00',
#  '9/1/2014 6:26:00',
#  '9/1/2014 6:35:00',
# ...
